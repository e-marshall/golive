# %%
import csv
import pandas as pd
import os

# %%
study_glaciers = pd.read_csv('written_files/study_glacier_shps.csv', sep=',', header = 0)
study_glaciers['RGIId'] = study_glaciers['RGIId'].str.replace('.', '_')
#study_glaciers
# Out:
#                  RGIId
# 0   RGI60_15_03976_shp
# 1   RGI60_15_04060_shp
# 2   RGI60_15_04119_shp
# 3   RGI60_15_04121_shp
# 4   RGI60_15_04137_shp
# 5   RGI60_15_04176_shp
# 6   RGI60_15_04220_shp
# 7   RGI60_15_04230_shp
# 8   RGI60_15_04258_shp
# 9   RGI60_15_09249_shp
# 10  RGI60_15_09255_shp
# 11  RGI60_15_09271_shp
# 12  RGI60_15_09283_shp
# 13  RGI60_15_09308_shp
# 14  RGI60_15_09338_shp
# 15  RGI60_15_09350_shp
# 16  RGI60_15_09354_shp
# 17  RGI60_15_09361_shp
# 18  RGI60_15_09377_shp
# 19  RGI60_15_09408_shp
# 20  RGI60_15_09426_shp
# 21  RGI60_15_09457_shp
# 22  RGI60_15_09459_shp
# 23  RGI60_15_09474_shp
# 24  RGI60_15_09475_shp
# 25  RGI60_15_09481_shp
# 26  RGI60_15_09483_shp
# 27  RGI60_15_09491_shp
# 28  RGI60_15_09492_shp
# 29  RGI60_15_09500_shp
# 30  RGI60_15_10255_shp
# 31  RGI60_15_10279_shp
# 32  RGI60_15_10285_shp
# 33  RGI60_15_10286_shp
# 34  RGI60_15_10290_shp
# 35  RGI60_15_10299_shp

# %%
filelist = os.listdir('/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/golive_full_scene')

for element in range(len(study_glaciers)):
        
    
    filename = study_glaciers['RGIId'][element][:-4]
    
    vx_dir = f"{filename}_clip_vxmask/"
    print(vx_dir)
    vy_dir = f"{filename}_clip_vymask/"
    vv_dir = f"{filename}_clip_vvmask/"
    corr_dir = f"{filename}_clip_corr/"
    del_corr_dir = f"{filename}_clip_del_corr/"
    del_i_dir = f"{filename}_clip_del_i/"
    del_j_dir = f"{filename}_clip_del_j/"
    
    vx_parent_path = '/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/'
    vy_parent_path = '/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/'
    vv_parent_path = '/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/'
    corr_parent_path ='/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/'
    del_corr_parent_path = '/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/'
    del_i_parent_path = '/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/'
    del_j_parent_path = '/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/' 
    
    vx_dir_path = os.path.join(vx_parent_path, vx_dir)
    vy_dir_path = os.path.join(vy_parent_path, vy_dir)
    vv_dir_path = os.path.join(vv_parent_path, vv_dir)
    
    corr_dir_path = os.path.join(corr_parent_path, corr_dir)
    del_corr_dir_path = os.path.join(del_corr_parent_path, del_corr_dir)
    del_i_dir_path = os.path.join(del_i_parent_path, del_i_dir)
    del_j_dir_path = os.path.join(del_j_parent_path, del_j_dir)
    
    #11-9 adding these to specify the filename after /AA_NOV_golive/each glacier/_______
    vx_fn = f"{filename}_clip_vxmask"
    vy_fn = f"{filename}_clip_vymask"
    vv_fn = f"{filename}_clip_vvmask"
    corr_fn = f"{filename}_clip_corr"
    del_corr_fn = f"{filename}_clip_del_corr"
    del_i_fn = f"{filename}_clip_del_i"
    del_j_fn = f"{filename}_clip_del_j"
    
    #these only need to be run once then comment out
    #os.mkdir(vx_dir_path)
    #os.mkdir(vy_dir_path)
    #os.mkdir(vv_dir_path)
    #os.mkdir(corr_dir_path)
    #os.mkdir(del_corr_dir_path)
    #os.mkdir(del_i_dir_path)
    #os.mkdir(del_j_dir_path)
# Out:
# RGI60_15_03976_clip_vxmask/
# RGI60_15_04060_clip_vxmask/
# RGI60_15_04119_clip_vxmask/
# RGI60_15_04121_clip_vxmask/
# RGI60_15_04137_clip_vxmask/
# RGI60_15_04176_clip_vxmask/
# RGI60_15_04220_clip_vxmask/
# RGI60_15_04230_clip_vxmask/
# RGI60_15_04258_clip_vxmask/
# RGI60_15_09249_clip_vxmask/
# RGI60_15_09255_clip_vxmask/
# RGI60_15_09271_clip_vxmask/
# RGI60_15_09283_clip_vxmask/
# RGI60_15_09308_clip_vxmask/
# RGI60_15_09338_clip_vxmask/
# RGI60_15_09350_clip_vxmask/
# RGI60_15_09354_clip_vxmask/
# RGI60_15_09361_clip_vxmask/
# RGI60_15_09377_clip_vxmask/
# RGI60_15_09408_clip_vxmask/
# RGI60_15_09426_clip_vxmask/
# RGI60_15_09457_clip_vxmask/
# RGI60_15_09459_clip_vxmask/
# RGI60_15_09474_clip_vxmask/
# RGI60_15_09475_clip_vxmask/
# RGI60_15_09481_clip_vxmask/
# RGI60_15_09483_clip_vxmask/
# RGI60_15_09491_clip_vxmask/
# RGI60_15_09492_clip_vxmask/
# RGI60_15_09500_clip_vxmask/
# RGI60_15_10255_clip_vxmask/
# RGI60_15_10279_clip_vxmask/
# RGI60_15_10285_clip_vxmask/
# ...

# %%
#study_glaciers = pd.read_csv('written_files/study_glacier_shps.csv', sep=',', header = 0)
filelist = os.listdir('/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/golive_full_scene')

# %%
for fp in filelist:
    
    for element in range(len(study_glaciers)):
        
        filename = study_glaciers['RGIId'][element][:-4]
        vx_dir1 = f"{filename}_clip_vxmask/"
        vx_fn = f"{filename}_clip_vxmask"
        tilename_x = 'PARENT PATH:' + vx_parent_path + '\n' + 'VX_DIR:' + vx_dir1 + '\n' + 'VX_FN:' + vx_fn + '_' + fp[:32] + '.nc'
        print(tilename_x)
        print('')
# Out:
# PARENT PATH:/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/
# VX_DIR:RGI60_15_03976_clip_vxmask/
# VX_FN:RGI60_15_03976_clip_vxmask_L8_141_040_016_2013_210_2013_226.nc
#
# PARENT PATH:/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/
# VX_DIR:RGI60_15_04060_clip_vxmask/
# VX_FN:RGI60_15_04060_clip_vxmask_L8_141_040_016_2013_210_2013_226.nc
#
# PARENT PATH:/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/
# VX_DIR:RGI60_15_04119_clip_vxmask/
# VX_FN:RGI60_15_04119_clip_vxmask_L8_141_040_016_2013_210_2013_226.nc
#
# PARENT PATH:/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/
# VX_DIR:RGI60_15_04121_clip_vxmask/
# VX_FN:RGI60_15_04121_clip_vxmask_L8_141_040_016_2013_210_2013_226.nc
#
# PARENT PATH:/uufs/chpc.utah.edu/common/home/u1269862/data/golive_dir/AA_GOLIVE_NOV/
# VX_DIR:RGI60_15_04137_clip_vxmask/
# VX_FN:RGI60_15_04137_clip_vxmask_L8_141_040_016_2013_210_2013_226.nc
#
# ...

# %%
for element in range(len(study_glaciers)):
    
    command = ""


    for fp in filelist:
        
            
        fullname = study_glaciers['RGIId'][element]
        filename = study_glaciers['RGIId'][element][:-4]

        #inputfile = fp
        
        vx_dir1 = f"{filename}_clip_vxmask/"
        vx_fn = f"{filename}_clip_vxmask"
        tilename_x = vx_parent_path  + vx_dir1 + vx_fn + '_' + fp[:32] + '.nc'
        
        vy_dir1 = f"{filename}_clip_vymask/"
        vy_fn = f"{filename}_clip_vymask"
        tilename_y = vy_parent_path + vy_dir1 + vy_fn + '_' + fp[:32] + '.nc'
        
        vv_dir1 = f"{filename}_clip_vvmask/"
        vv_fn = f"{filename}_clip_vvmask"
        tilename_v = vv_parent_path + vv_dir1 + vv_fn + '_' + fp[:32] + '.nc'
        
        corr_dir1 = f"{filename}_clip_corr/"
        corr_fn = f"{filename}_clip_corr"
        tilename_corr = corr_parent_path + corr_dir1 + corr_fn + '_' + fp[:32] + '.nc'
        
        del_corr_dir1 = f"{filename}_clip_del_corr/"
        del_corr_fn = f"{filename}_clip_del_corr"
        tilename_del_corr = del_corr_parent_path + del_corr_dir1 + del_corr_fn + '_' + fp[:32] + '.nc'
        
        #del_i_dir1 = f"{filename}_clip_del_i/"
        #del_i_fn = f"{filename}_clip_del_i"
        #tilename_del_i = del_i_parent_path + del_i_dir1 + del_i_fn + '_' + fp[:32] + '.nc'
        
        #del_j_dir1 = f"{filename}_clip_del_j/"
        #del_j_fn = f"{filename}_clip_del_j"
        #tilename_del_j = del_j_parent_path + del_j_dir1 + del_j_fn + '_' + fp[:32] + '.nc'

        #tilename_x = vx_parent_path + vx_dir + vx_fn + '_' + fp[:32] + '.nc'
        #tilename_y = vy_parent_path + vy_dir + vy_fn + '_' + fp[:32] + '.nc'
        #tilename_v = vv_parent_path + vv_dir + vv_fn + '_' + fp[:32] + '.nc'
        #tilename_corr = corr_parent_path + corr_dir + corr_fn + '_' + fp[:32] + '.nc'
        #tilename_del_corr = del_corr_parent_path + del_corr_dir + del_corr_fn + '-' + fp[:32] + '.nc'
        #tilename_del_i = del_i_parent_path + del_i_dir + del_i_fn + '_' + fp[:32] + '.nc'
        #tilename_del_j = del_j_parent_path + del_j_dir + del_j_fn + '_' + fp[:32] + '.nc'
        
        #outputfile_x = tile_name_x + '_vxmask_clip.nc'
        #outputfile_y = tile_name_y + '_vymask_clip.nc'
        #outputfile_v = tile_name_v + '_vvmask_clip.nc'
        #outputfile_corr = tile_name_corr + '_corr_clip.nc'
        #outputfile_del_corr = tile_name_del_corr + '_del_corr_clip.nc'
        #outputfile_del_i = tile_name_del_i + '_del_i_clip.nc'
        #outputfile_del_j = tile_name_del_j + '_del_j_clip.nc' 
        
        command += f"gdalwarp -cutline /uufs/chpc.utah.edu/common/home/u1269862/written_files/study_glaciers_112/{fullname} -s_srs EPSG:32645 -crop_to_cutline -co UNIFIED_SRC_NODATA=YES NETCDF:{fp}:vx_masked {tilename_x}\n"
        command += f"gdalwarp -cutline /uufs/chpc.utah.edu/common/home/u1269862/written_files/study_glaciers_112/{fullname} -s_srs EPSG:32645 -crop_to_cutline -co UNIFIED_SRC_NODATA=YES NETCDF:{fp}:vy_masked {tilename_y}\n"
        command += f"gdalwarp -cutline /uufs/chpc.utah.edu/common/home/u1269862/written_files/study_glaciers_112/{fullname} -s_srs EPSG:32645 -crop_to_cutline -co UNIFIED_SRC_NODATA=YES NETCDF:{fp}:vv_masked {tilename_v}\n"
        #command += f"gdalwarp -cutline /uufs/chpc.utah.edu/common/home/u1269862/written_files/study_glaciers_112/{fullname} -s_srs EPSG:32645 -crop_to_cutline -co UNIFIED_SRC_NODATA=YES NETCDF:{fp}:corr {tilename_corr}\n"
        #command += f"gdalwarp -cutline /uufs/chpc.utah.edu/common/home/u1269862/written_files/study_glaciers_112/{fullname} -s_srs EPSG:32645 -crop_to_cutline -co UNIFIED_SRC_NODATA=YES NETCDF:{fp}:del_corr {tilename_del_corr}\n"
        #command += f"gdalwarp -cutline /uufs/chpc.utah.edu/common/home/u1269862/written_files/study_glaciers_112/{fullname} -s_srs EPSG:32645 -crop_to_cutline -co UNIFIED_SRC_NODATA=YES NETCDF:{fp}:del_i {tilename_del_i}\n"
        #command += f"gdalwarp -cutline /uufs/chpc.utah.edu/common/home/u1269862/written_files/study_glaciers_112/{fullname} -s_srs EPSG:32645 -crop_to_cutline -co UNIFIED_SRC_NODATA=YES NETCDF:{fp}:del_j {tilename_del_j}\n"
     
    
        
    #write command to .sh file
    cmd_file = f"/uufs/chpc.utah.edu/common/home/u1269862/gdal_commands/AA_NOV_glacier_clipping/{filename}_ClipGlacierOutline.sh"
    f = open(os.path.join(cmd_file), 'w')

    f.write(command)
    f.close()
